# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/pandas-python/blob/main/pandas-learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#criando um dataframe
#dataframe = pd.DataFrame()
#criando um  dicionário de vendas durante a semana do mês 09de marmitas
vendas_marmitas ={
  'data' : ['17/09/2023', '22/09/23'],
  'lucro': [300,500],
  'empresa':['BetaLog','TagLog'],
  'quantidade':[200,300]
}
#dataframes, podem ser dicionários, tabelas e banco de dados
#criar um dataframe a partir de um dicionário
vendas_marmitas_df = pd.DataFrame(vendas_marmitas)
#display, imprime dataframe de maneira estilizada
display(vendas_marmitas_df)
# Out:
#          data  lucro  empresa  quantidade
# 0  17/09/2023    300  BetaLog         200
# 1    22/09/23    500   TagLog         300

# %% [markdown]
# # Nova seção

# %% [markdown]
# Abrindo arquivo externo

# %%
vendas_df = pd.read_excel('Vendas.xlsx')
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %%
#mostra as 5 primeiras linhas
#se quiser colocar mais linhas, faça vendas_df.head(10) para as 10 primeiras linhas
#mostrando as 10 primeiras linhas
display(vendas_df.head(10))
#metodo shapr, mostra linhas e colunas
print(vendas_df.shape)
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# ...

# %%
#metodo describe
#metodo describe, mostra o resumo do dataframe
display(vendas_df.describe())
# Out:
#        Código Venda    Quantidade  Valor Unitário   Valor Final
# count  93910.000000  93910.000000    93910.000000  93910.000000
# mean   32464.762155      2.166553      191.725886    414.862656
# std    18809.007093      1.258732      145.215519    434.846228
# min        1.000000      1.000000       30.000000     30.000000
# 25%    16204.000000      1.000000      100.000000    156.000000
# 50%    32367.000000      2.000000      155.000000    274.000000
# 75%    48793.750000      3.000000      248.000000    524.000000
# max    65014.000000      5.000000      750.000000   3750.000000

# %%
#ediçao da data frame
#pegar a coluna produto
produtos = vendas_df[['Produto','ID Loja']]
#nao eh um data frame, uma serie do pandas
#serie do pandas, sao colunas do data frame
display(produtos)
# Out:
#                  Produto              ID Loja
# 0         Sapato Estampa   Iguatemi Esplanada
# 1               Camiseta   Iguatemi Esplanada
# 2          Sapato Xadrez   Iguatemi Esplanada
# 3                Relógio       Norte Shopping
# 4           Chinelo Liso       Norte Shopping
# ...                  ...                  ...
# 93905     Mochila Xadrez  Shopping Vila Velha
# 93906  Pulseira Listrado    Ribeirão Shopping
# 93907     Cueca Listrado    Ribeirão Shopping
# 93908     Pulseira Linho     Shopping Morumbi
# 93909      Casaco Xadrez     Shopping Morumbi
#
# [93910 rows x 2 columns]

# %%
#metodo loc
#pegar 1 linha
indice=vendas_df.loc[1:5]
display(indice)
# Out:
#    Código Venda       Data                     ID Loja        Produto  \
# 1             1 2019-01-01          Iguatemi Esplanada       Camiseta
# 2             1 2019-01-01          Iguatemi Esplanada  Sapato Xadrez
# 3             2 2019-01-02              Norte Shopping        Relógio
# 4             2 2019-01-02              Norte Shopping   Chinelo Liso
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza    Cinto Linho
#
#    Quantidade  Valor Unitário  Valor Final
# 1           2             180          360
# 2           1             368          368
# 3           3             200          600
# 4           1              71           71
# 5           1             248          248

# %%
#metodo loc
#pegar linhas que correspondem a uma condiçao

norte_shopping = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping']
display(norte_shopping)
# Out:
#        Código Venda       Data         ID Loja                 Produto  \
# 3                 2 2019-01-02  Norte Shopping                 Relógio
# 4                 2 2019-01-02  Norte Shopping            Chinelo Liso
# 8                 7 2019-01-02  Norte Shopping  Camisa Gola V Listrado
# 9                 7 2019-01-02  Norte Shopping             Camisa Liso
# 100              73 2019-01-02  Norte Shopping            Cueca Xadrez
# ...             ...        ...             ...                     ...
# 93716         64888 2019-11-30  Norte Shopping             Polo Xadrez
# 93754         64914 2019-11-30  Norte Shopping              Calça Liso
# 93755         64914 2019-11-30  Norte Shopping          Casaco Estampa
# 93756         64914 2019-11-30  Norte Shopping                   Gorro
# 93852         64980 2019-11-30  Norte Shopping           Bermuda Linho
#
#        Quantidade  Valor Unitário  Valor Final
# 3               3             200          600
# ...

# %%
#pegar varias linhas e colunas com loc
norte_shopping = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping', ['ID Loja','Produto','Quantidade']]
display(norte_shopping)
# Out:
#               ID Loja                 Produto  Quantidade
# 3      Norte Shopping                 Relógio           3
# 4      Norte Shopping            Chinelo Liso           1
# 8      Norte Shopping  Camisa Gola V Listrado           1
# 9      Norte Shopping             Camisa Liso           1
# 100    Norte Shopping            Cueca Xadrez           5
# ...               ...                     ...         ...
# 93716  Norte Shopping             Polo Xadrez           1
# 93754  Norte Shopping              Calça Liso           1
# 93755  Norte Shopping          Casaco Estampa           2
# 93756  Norte Shopping                   Gorro           2
# 93852  Norte Shopping           Bermuda Linho           1
#
# [3924 rows x 3 columns]

# %%
#pegar 1 linha e 1 coluna
#pegando o produto que eh camiseta, na linha 01 da coluna Produto
produto_linha_1 = vendas_df.loc[1, 'Produto']
display(produto_linha_1)
# Out:
# 'Camiseta'

# %%
#adicionar 1 coluna nova
#a partir de uma coluna que existe
vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão
# 0               1             358          358     17.90
# ...

# %%
#partir de valores padrao
vendas_df.loc[:,'Imposto'] =0
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# ...

# %%
#adicionar 1 linha
vendas_dezembro_df = pd.read_excel('Vendas - Dez.xlsx')
display(vendas_dezembro_df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
vendas_df = vendas_df.append(vendas_dezembro_df)
display(vendas_df)
# Out:
# <ipython-input-39-739a0046d380>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vendas_df = vendas_df.append(vendas_dezembro_df)
#       Código Venda       Data                     ID Loja           Produto  \
# 0                1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# ...

# %%
vendas_df_filtro = vendas_df.loc[vendas_df['Data']=='2019-12-26']
display(vendas_df_filtro)
#vendas_df=vendas_df.dropna(how='all',axis=1)
#display(vendas_df)
#deletar linha e/ou coluna vazia
#vendas_df = vendas_df.dropna()
#display(vendas_df)
#preenchendo colunas
#vendas_df['Comissão'] = vendas_df['Comissão'].fillna(1)
#ou com vendas_df['Comissão'] = vendas_df['Comissão'].mena()
#display(vendas_df)
# Out:
#       Código Venda       Data                           ID Loja  \
# 7050         69970 2019-12-26               Shopping Vila Velha
# 7051         69971 2019-12-26                   Shopping Recife
# 7052         69971 2019-12-26                   Shopping Recife
# 7053         69972 2019-12-26                 Salvador Shopping
# 7054         69972 2019-12-26                 Salvador Shopping
# 7055         69974 2019-12-26               Shopping Vila Velha
# 7056         69975 2019-12-26  Shopping Center Leste Aricanduva
# 7057         69975 2019-12-26  Shopping Center Leste Aricanduva
# 7058         69976 2019-12-26                    Norte Shopping
# 7059         69976 2019-12-26                    Norte Shopping
# 7060         69977 2019-12-26               Shopping Ibirapuera
# 7061         69978 2019-12-26        Shopping Center Interlagos
# 7062         69978 2019-12-26        Shopping Center Interlagos
# 7063         69979 2019-12-26          Shopping União de Osasco
# ...

# %%
vendas_dez_df=vendas_df_filtro['Data']
display(vendas_dez_df)
# Out:
# 7050   2019-12-26
# 7051   2019-12-26
# 7052   2019-12-26
# 7053   2019-12-26
# 7054   2019-12-26
# 7055   2019-12-26
# 7056   2019-12-26
# 7057   2019-12-26
# 7058   2019-12-26
# 7059   2019-12-26
# 7060   2019-12-26
# 7061   2019-12-26
# 7062   2019-12-26
# 7063   2019-12-26
# 7064   2019-12-26
# 7065   2019-12-26
# 7066   2019-12-26
# 7067   2019-12-26
# 7068   2019-12-26
# 7069   2019-12-26
# 7070   2019-12-26
# 7071   2019-12-26
# 7072   2019-12-26
# 7073   2019-12-26
# 7074   2019-12-26
# 7075   2019-12-26
# 7076   2019-12-26
# 7077   2019-12-26
# 7078   2019-12-26
# 7079   2019-12-26
# 7080   2019-12-26
# 7081   2019-12-26
# 7082   2019-12-26
# 7083   2019-12-26
# 7084   2019-12-26
# 7085   2019-12-26
# 7086   2019-12-26
# 7087   2019-12-26
# 7088   2019-12-26
# Name: Data, dtype: datetime64[ns]

# %%
vendas_de_dezembro_df = vendas_df.loc[vendas_df['Data']=='2019-12-26',['ID Loja','Produto','Quantidade','Valor Final','Comissão']]
display(vendas_de_dezembro_df)
# Out:
#                                ID Loja                Produto  Quantidade  \
# 7050               Shopping Vila Velha           Casaco Linho           2
# 7051                   Shopping Recife             Cinto Liso           2
# 7052                   Shopping Recife       Bermuda Listrado           2
# 7053                 Salvador Shopping             Terno Liso           3
# 7054                 Salvador Shopping         Sapato Estampa           5
# 7055               Shopping Vila Velha          Meia Listrado           3
# 7056  Shopping Center Leste Aricanduva          Cueca Estampa           5
# 7057  Shopping Center Leste Aricanduva         Bermuda Xadrez           1
# 7058                    Norte Shopping           Tênis Xadrez           1
# 7059                    Norte Shopping                 Casaco           4
# 7060               Shopping Ibirapuera  Camisa Gola V Estampa           1
# 7061        Shopping Center Interlagos           Gorro Xadrez           2
# ...

# %%
comissao_dezembro=vendas_de_dezembro_df.loc[:,'Comissão'] = vendas_de_dezembro_df['Valor Final'] *0.05
display(comissao_dezembro)
# Out:
# 7050     29.90
# 7051     20.90
# 7052     16.30
# 7053    108.00
# 7054     89.50
# 7055      5.55
# 7056     16.50
# 7057      7.75
# 7058     12.95
# 7059     50.00
# 7060      5.90
# 7061      8.50
# 7062     70.60
# 7063     10.00
# 7064     41.55
# 7065      8.80
# 7066     14.95
# 7067     58.80
# 7068      9.80
# 7069      3.90
# 7070     11.40
# 7071     31.10
# 7072      4.10
# 7073     13.80
# 7074     11.40
# 7075     13.20
# 7076    106.35
# 7077     33.80
# 7078     54.00
# 7079     10.00
# 7080     18.40
# 7081      8.50
# 7082     32.10
# 7083     54.00
# 7084     10.20
# 7085     54.00
# 7086      4.35
# 7087      5.40
# 7088     13.30
# Name: Valor Final, dtype: float64

# %%
vendas_de_dezembro_df.append(comissao_dezembro)
display(vendas_de_dezembro_df)
# Out:
# <ipython-input-22-aa9c8b560b95>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vendas_de_dezembro_df.append(comissao_dezembro)
#                                ID Loja                Produto  Quantidade  \
# 7050               Shopping Vila Velha           Casaco Linho           2
# 7051                   Shopping Recife             Cinto Liso           2
# 7052                   Shopping Recife       Bermuda Listrado           2
# 7053                 Salvador Shopping             Terno Liso           3
# 7054                 Salvador Shopping         Sapato Estampa           5
# 7055               Shopping Vila Velha          Meia Listrado           3
# 7056  Shopping Center Leste Aricanduva          Cueca Estampa           5
# 7057  Shopping Center Leste Aricanduva         Bermuda Xadrez           1
# 7058                    Norte Shopping           Tênis Xadrez           1
# ...

# %%
vendas_de_dezembro_df['Média'] = sum(vendas_de_dezembro_df['Valor Final'])/len(vendas_de_dezembro_df['Valor Final'])
vendas_de_dezembro_df['Comissão'] = vendas_de_dezembro_df['Comissão'].mean()
display(vendas_de_dezembro_df)
# Out:
#                                ID Loja                Produto  Quantidade  \
# 7050               Shopping Vila Velha           Casaco Linho           2
# 7051                   Shopping Recife             Cinto Liso           2
# 7052                   Shopping Recife       Bermuda Listrado           2
# 7053                 Salvador Shopping             Terno Liso           3
# 7054                 Salvador Shopping         Sapato Estampa           5
# 7055               Shopping Vila Velha          Meia Listrado           3
# 7056  Shopping Center Leste Aricanduva          Cueca Estampa           5
# 7057  Shopping Center Leste Aricanduva         Bermuda Xadrez           1
# 7058                    Norte Shopping           Tênis Xadrez           1
# 7059                    Norte Shopping                 Casaco           4
# 7060               Shopping Ibirapuera  Camisa Gola V Estampa           1
# 7061        Shopping Center Interlagos           Gorro Xadrez           2
# ...

# %%
produto_casaco_linho = vendas_de_dezembro_df.loc[7050, ['ID Loja', 'Produto', 'Quantidade','Comissão', 'Média']]
display(produto_casaco_linho)
# Out:
# ID Loja       Shopping Vila Velha
# Produto              Casaco Linho
# Quantidade                      2
# Comissão                     29.9
# Média                  553.615385
# Name: 7050, dtype: object

# %%
vendas_de_dezembro_df.loc[:,'Estoque']=1000
display(vendas_de_dezembro_df)
# Out:
#                                ID Loja                Produto  Quantidade  \
# 7050               Shopping Vila Velha           Casaco Linho           2
# 7051                   Shopping Recife             Cinto Liso           2
# 7052                   Shopping Recife       Bermuda Listrado           2
# 7053                 Salvador Shopping             Terno Liso           3
# 7054                 Salvador Shopping         Sapato Estampa           5
# 7055               Shopping Vila Velha          Meia Listrado           3
# 7056  Shopping Center Leste Aricanduva          Cueca Estampa           5
# 7057  Shopping Center Leste Aricanduva         Bermuda Xadrez           1
# 7058                    Norte Shopping           Tênis Xadrez           1
# 7059                    Norte Shopping                 Casaco           4
# 7060               Shopping Ibirapuera  Camisa Gola V Estampa           1
# 7061        Shopping Center Interlagos           Gorro Xadrez           2
# ...

# %%
#calcular indicadores
